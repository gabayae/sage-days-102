# %% [markdown]
# <h1 style="text-align: left;"><a title="Sage Days 102 Workshop" href="https://wiki.sagemath.org/days102">Sage Days 102 Workshop</a>, <a title="University of Ibadan" href="https://www.ui.edu.ng/">University of Ibadan</a> Nigeria.</h1>
#
#
# <h2 style="text-align: left;">Day 02 — Introduction to <a title="Sage"href="http://www.sagemath.org/"><em>Sage</em></a>: A Mathematics Software for All</h2>
#
#
# ### Instructor: [Evans Doe Ocansey](https://risc.jku.at/m/evans-doe-ocansey/)
#
# The outline of the this notebook is as follows:

# %% [markdown]
# ## Table of Contents: <a class="anchor" id="toc"></a>
# * [ ]   [<font color=blue>What is SageMath?</font>](./sage_days_102_introduction_to_sage_01_what_is_sage.ipynb#what-is-sage)
#     * [ ]  [<font color=blue>A Brief Overview</font>](./sage_days_102_introduction_to_sage_01_what_is_sage.ipynb#brief-overview)
#     * [ ]  [<font color=blue>Using Other Non-Commercial Softwares</font>](./sage_days_102_introduction_to_sage_01_what_is_sage.ipynb#using-non-commerical-softwares)
# * [ ]   [<font color=blue>Help Inside Sage</font>](./sage_days_102_introduction_to_sage_02_help_inside_sage.ipynb#help-inside-sage)
#     * [ ]   [<font color=blue>Documentation</font>](./sage_days_102_introduction_to_sage_02_help_inside_sage.ipynb#documentation)
#     * [ ]   [<font color=blue>Tab Completion</font>](./sage_days_102_introduction_to_sage_02_help_inside_sage.ipynb#tab-completion)
# * [ ]   [<font color=blue>Complete Access to Source Code</font>](./sage_days_102_introduction_to_sage_03_access_to_source_code.ipynb#access-to-source-code)
#     * [ ]   [<font color=red>Exercise 1</font>](./sage_days_102_introduction_to_sage_03_access_to_source_code.ipynb#exercise-1)
# * [ ]   [<font color=blue>Just the Basics</font>](./sage_days_102_introduction_to_sage_04_just_the_basics.ipynb#just-the-basics)
#     * [ ]   [<font color=blue>Sage as a Calculator</font>](./sage_days_102_introduction_to_sage_04_just_the_basics.ipynb#sage-as-a-calculator)
#     * [ ]   [<font color=blue>Elementary Functions and Usual Constants</font>](./sage_days_102_introduction_to_sage_04_just_the_basics.ipynb#elementary-functions-and-usual-constants)
#     * [ ]   [<font color=blue>Python Variables</font>](./sage_days_102_introduction_to_sage_04_just_the_basics.ipynb#python-variables)
#     * [ ]   [<font color=blue>Symbolic Variables</font>](./sage_days_102_introduction_to_sage_04_just_the_basics.ipynb#symbolic-variables)
#         * [ ]   [<font color=red>Exercise 2</font>](./sage_days_102_introduction_to_sage_04_just_the_basics.ipynb#exercise-2)
#     * [ ]   [<font color=blue>Plotting in Brief</font>](./sage_days_102_introduction_to_sage_04_just_the_basics.ipynb#plotting-in-brief)
# * [ ]   [<font color=blue>Algebra and Analysis</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#algebra-and-analysis)
#     * [ ]   [<font color=blue>Symbolic Expressions</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#symbolic-expressions)
#     * [ ]   [<font color=blue>Transforming Expressions</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#transforming-expressions)
#         * [ ]   [<font color=red>Exercise 3</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#exercise-3)
#     * [ ]   [<font color=blue>Usual Mathematical Functions</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#usual-mathematical-functions)
#     * [ ]   [<font color=blue>Assumptions</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#assumptions)
#     * [ ]   [<font color=blue>Equations</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#equations)
#     * [ ]   [<font color=blue>Explicit Solving</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#explicit-solving)
#         * [ ]   [<font color=red>Exercise 4</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#exercise-4)
#         * [ ]   [<font color=red>Exercise 5</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#exercise-5)
#         * [ ]   [<font color=red>Exercise 6</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#exercise-6)
#         * [ ]   [<font color=red>Exercise 7</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#exercise-7)
#         * [ ]   [<font color=red>Exercise 8</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#exercise-8)
#     * [ ]   [<font color=blue>Equations with no Explicit Solution</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#equations-with-no-explicit-solution)
#     * [ ]   [<font color=blue>Analysis</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#analysis)
#         * [ ]   [<font color=blue>Sums</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#sums)
#         * [ ]   [<font color=blue>Limits</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#limits)
#             * [ ]   [<font color=red>Exercise 9</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#exercise-9)
#         * [ ]   [<font color=blue>Sequences</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#sequences)
#             * [ ]   [<font color=red>Exercise 10</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#exercise-10)
#         * [ ]   [<font color=blue>Power Series Expansions</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#power-series-expansions)
#             * [ ]   [<font color=red>Exercise 11</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#exercise-11)
#             * [ ]   [<font color=red>Exercise 12</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#exercise-12)
#             * [ ]   [<font color=red>Exercise 13</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#exercise-13)
#         * [ ]   [<font color=blue>Series</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#series)
#             * [ ]   [<font color=red>Exercise 14</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#exercise-14)
#             * [ ]   [<font color=red>Exercise 15</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#exercise-15)
#         * [ ]   [<font color=blue>Derivatives</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#derivatives)
#         * [ ]   [<font color=blue>Partial Derivatives</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#partial-derivatives)
#             * [ ]   [<font color=red>Exercise 16</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#exercise-16)
#             * [ ]   [<font color=red>Exercise 17</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#exercise-17)
#         * [ ]   [<font color=blue>Integrals</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#integrals)
#             * [ ]   [<font color=red>Exercise 18</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#exercise-18)
#     * [ ]   [<font color=blue>Basic Linear Algebra</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#basic-linear-algebra)
#         * [ ]   [<font color=blue>Vector Computations</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#vector-computations)
#             * [ ]   [<font color=red>Exercise 19</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#exercise-19)
#             * [ ]   [<font color=red>Exercise 20</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#exercise-20)
#         * [ ]   [<font color=blue>Matrix Computations</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#matrix-computations)
#             * [ ]   [<font color=red>Exercise 21</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#exercise-21)
#             * [ ]   [<font color=blue>Reduction of a Square Matrix</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#reduction-of-a-square-matrix)
#                 * [ ]   [<font color=red>Exercise 22</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#exercise-22)
#                 * [ ]   [<font color=red>Exercise 23</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#exercise-23)
#                 * [ ]   [<font color=red>Exercise 24</font>](./sage_days_102_introduction_to_sage_05_algebra_and_analysis.ipynb#exercise-24)
# * [ ]   [<font color=blue>Object Oriented Paradigm</font>](./sage_days_102_introduction_to_sage_06_object_oriented_paradigm.ipynb#object-oriented-paradigm)
#     * [ ]   [<font color=red>Exercise 25</font>](./sage_days_102_introduction_to_sage_06_object_oriented_paradigm.ipynb#exercise-25)
#     * [ ]   [<font color=red>Exercise 26</font>](./sage_days_102_introduction_to_sage_06_object_oriented_paradigm.ipynb#exercise-26)
# * [ ]   [<font color=blue>Expressions and Computational Domains</font>](./sage_days_102_introduction_to_sage_07_expressions_and_computational_domains.ipynb#exprs-and-comp-domains)
#     * [ ]   [<font color=red>Exercise 27</font>](./sage_days_102_introduction_to_sage_07_expressions_and_computational_domains.ipynb#exercise-27)
# * [ ]   [<font color=blue>Python Programming Constructs — Revision</font>](./sage_days_102_introduction_to_sage_08_python_programming_constructs.ipynb#python-pgrm-constructs-revision)
#     * [ ]   [<font color=blue>Loops</font>](./sage_days_102_introduction_to_sage_08_python_programming_constructs.ipynb#loops)
#         * [ ]   [<font color=blue>For Loops</font>](./sage_days_102_introduction_to_sage_08_python_programming_constructs.ipynb#for-loops)
#             * [ ]   [<font color=red>Exercise 28</font>](./sage_days_102_introduction_to_sage_08_python_programming_constructs.ipynb#exercise-28)
#             * [ ]   [<font color=red>Exercise 29</font>](./sage_days_102_introduction_to_sage_08_python_programming_constructs.ipynb#exercise-29)
#         * [ ]   [<font color=blue>While Loops</font>](./sage_days_102_introduction_to_sage_08_python_programming_constructs.ipynb#while-loops)
#             * [ ]   [<font color=red>Exercise 30</font>](./sage_days_102_introduction_to_sage_08_python_programming_constructs.ipynb#exercise-30)
#             * [ ]   [<font color=red>Exercise 31</font>](./sage_days_102_introduction_to_sage_08_python_programming_constructs.ipynb#exercise-31)
#         * [ ]   [<font color=blue>Conditionals</font>](./sage_days_102_introduction_to_sage_08_python_programming_constructs.ipynb#conditionals)
#             * [ ]   [<font color=red>Exercise 32</font>](./sage_days_102_introduction_to_sage_08_python_programming_constructs.ipynb#exercise-32)
#         * [ ]   [<font color=blue>Functions and Procedures</font>](./sage_days_102_introduction_to_sage_08_python_programming_constructs.ipynb#functions-and-procedures)
#             * [ ]   [<font color=red>Exercise 33</font>](./sage_days_102_introduction_to_sage_08_python_programming_constructs.ipynb#exercise-33)
#             * [ ]   [<font color=red>Exercise 34</font>](./sage_days_102_introduction_to_sage_08_python_programming_constructs.ipynb#exercise-34)
#             * [ ]   [<font color=red>Exercise 35</font>](./sage_days_102_introduction_to_sage_08_python_programming_constructs.ipynb#exercise-35)
#         * [ ]   [<font color=blue>Lambda Functions</font>](./sage_days_102_introduction_to_sage_08_python_programming_constructs.ipynb#lambda-functions)
#             * [ ]   [<font color=red>Exercise 36</font>](./sage_days_102_introduction_to_sage_08_python_programming_constructs.ipynb#exercise-36)
#         * [ ]   [<font color=blue>Recursive Functions</font>](./sage_days_102_introduction_to_sage_08_python_programming_constructs.ipynb#recursive-functions)
#             * [ ]   [<font color=red>Exercise 37</font>](./sage_days_102_introduction_to_sage_08_python_programming_constructs.ipynb#exercise-37)
#             * [ ]   [<font color=red>Exercise 38</font>](./sage_days_102_introduction_to_sage_08_python_programming_constructs.ipynb#exercise-38)
#             * [ ]   [<font color=red>Exercise 39</font>](./sage_days_102_introduction_to_sage_08_python_programming_constructs.ipynb#exercise-39)
#             * [ ]   [<font color=red>Exercise 40</font>](./sage_days_102_introduction_to_sage_08_python_programming_constructs.ipynb#exercise-40)
# * [ ]   [<font color=blue>Sage Symbolic Expressions and Symbolic Functions</font>](./sage_days_102_introduction_to_sage_09_symbolic_expressions_and_symbolic_functions.ipynb#sage-symb-exprs-and-symb-functions)
# * [ ]   [<font color=blue>Python Data Types — Revision</font>](./sage_days_102_introduction_to_sage_10_python_data_types.ipynb#python-data-types-revision)
#     * [ ]   [<font color=blue>List</font>](./sage_days_102_introduction_to_sage_10_python_data_types.ipynb#list)
#         * [ ]   [<font color=blue>List Methods</font>](./sage_days_102_introduction_to_sage_10_python_data_types.ipynb#list-methods)
#             * [ ]   [<font color=red>Exercise 41</font>](./sage_days_102_introduction_to_sage_10_python_data_types.ipynb#exercise-41)
#         * [ ]   [<font color=blue>Slicing & Modifying List Objects</font>](./sage_days_102_introduction_to_sage_10_python_data_types.ipynb#slicing-and-modifying-list-objs)
#         * [ ]   [<font color=blue>Other Operations on List Objects</font>](./sage_days_102_introduction_to_sage_10_python_data_types.ipynb#other-operations-on-list-objs)
#             * [ ]   [<font color=red>Exercise 42</font>](./sage_days_102_introduction_to_sage_10_python_data_types.ipynb#exercise-42)
#             * [ ]   [<font color=red>Exercise 43</font>](./sage_days_102_introduction_to_sage_10_python_data_types.ipynb#exercise-43)
#         * [ ]   [<font color=blue>List Comprehension</font>](./sage_days_102_introduction_to_sage_10_python_data_types.ipynb#list-comprehension)
#             * [ ]   [<font color=red>Exercise 44</font>](./sage_days_102_introduction_to_sage_10_python_data_types.ipynb#exercise-44)
#             * [ ]   [<font color=red>Exercise 45</font>](./sage_days_102_introduction_to_sage_10_python_data_types.ipynb#exercise-45)
#     * [ ]   [<font color=blue>Tuples</font>](./sage_days_102_introduction_to_sage_10_python_data_types.ipynb#tuples)
#         * [ ]   [<font color=blue>Tuple Methods</font>](./sage_days_102_introduction_to_sage_10_python_data_types.ipynb#tuple-methods)
#         * [ ]   [<font color=blue>Tuple Slicing</font>](./sage_days_102_introduction_to_sage_10_python_data_types.ipynb#tuple-slicing)
#             * [ ]   [<font color=red>Exercise 46</font>](./sage_days_102_introduction_to_sage_10_python_data_types.ipynb#exercise-46)
#         * [ ]   [<font color=blue>Tuple Comprehension</font>](./sage_days_102_introduction_to_sage_10_python_data_types.ipynb#tuple-comprehension)
#     * [ ]   [<font color=blue>Dictionaries</font>](./sage_days_102_introduction_to_sage_10_python_data_types.ipynb#dictionaries)
#         * [ ]   [<font color=blue>Dictionary Methods</font>](./sage_days_102_introduction_to_sage_10_python_data_types.ipynb#dictionary-methods)
#             * [ ]   [<font color=red>Exercise 47</font>](./sage_days_102_introduction_to_sage_10_python_data_types.ipynb#exercise-47)
#         * [ ]   [<font color=blue>Dictionary Comprehension</font>](./sage_days_102_introduction_to_sage_10_python_data_types.ipynb#dictionary-comprehension)
#             * [ ]   [<font color=red>Exercise 48</font>](./sage_days_102_introduction_to_sage_10_python_data_types.ipynb#exercise-48)
# * [ ]   [<font color=blue>Graphics</font>](./sage_days_102_introduction_to_sage_11_graphics.ipynb#graphics)
#     * [ ]   [<font color=blue>2D Graphics</font>](./sage_days_102_introduction_to_sage_11_graphics.ipynb#2d-graphics)
#         * [ ]   [<font color=blue>Graphical Representation of a function</font>](./sage_days_102_introduction_to_sage_11_graphics.ipynb#graphical-representation-of-a-function)
#             * [ ]   [<font color=red>Exercise 49</font>](./sage_days_102_introduction_to_sage_11_graphics.ipynb#exercise-49)
#             * [ ]   [<font color=red>Exercise 50</font>](./sage_days_102_introduction_to_sage_11_graphics.ipynb#exercise-50)
#             * [ ]   [<font color=red>Exercise 51</font>](./sage_days_102_introduction_to_sage_11_graphics.ipynb#exercise-51)
#             * [ ]   [<font color=red>Exercise 52</font>](./sage_days_102_introduction_to_sage_11_graphics.ipynb#exercise-52)
#         * [ ]   [<font color=blue>Parametric Curve</font>](./sage_days_102_introduction_to_sage_11_graphics.ipynb#parametric-curve)
#             * [ ]   [<font color=red>Exercise 53</font>](./sage_days_102_introduction_to_sage_11_graphics.ipynb#exercise-53)
#         * [ ]   [<font color=blue>Curves in Polar Coordinates</font>](./sage_days_102_introduction_to_sage_11_graphics.ipynb#curves-in-polar-coordinates)
#             * [ ]   [<font color=red>Exercise 54</font>](./sage_days_102_introduction_to_sage_11_graphics.ipynb#exercise-54)
#         * [ ]   [<font color=blue>Curve Defined by an Implicit Equation</font>](./sage_days_102_introduction_to_sage_11_graphics.ipynb#curve-defined-by-an-implicit-equation)
#             * [ ]   [<font color=red>Exercise 55</font>](./sage_days_102_introduction_to_sage_11_graphics.ipynb#exercise-55)
#         * [ ]   [<font color=blue>Data Visualisation</font>](./sage_days_102_introduction_to_sage_11_graphics.ipynb#data-visualisation)
#         * [ ]   [<font color=blue>List of 2D Plotting Commands in Sage and Some Examples</font>](./sage_days_102_introduction_to_sage_11_graphics.ipynb#list-of-2d-plotting-commands-in-sage-and-some-examples)
#     * [ ]   [<font color=blue>3D Graphics</font>](./sage_days_102_introduction_to_sage_11_graphics.ipynb#3d-graphics)
#     * [ ]   [<font color=blue>Interact</font>](./sage_days_102_introduction_to_sage_11_graphics.ipynb#interact)
#         * [ ]   [<font color=blue>Control Types</font>](./sage_days_102_introduction_to_sage_11_graphics.ipynb#control-types)
#         * [ ]   [<font color=blue>Interact Competition</font>](./sage_days_102_introduction_to_sage_11_graphics.ipynb#interact-competition)
# * [ ]   [<font color=blue>$\TeX$ in Sage</font>](./sage_days_102_introduction_to_sage_12_tex_in_sage.ipynb#tex-in-sage)
# * [ ]   [<font color=blue>Sage Outside Jupyter Notebook</font>](./sage_days_102_introduction_to_sage_13_sage_outside_jupyter_notebook.ipynb#sage-outside-jupyter-notebook)
#     * [ ]   [<font color=blue>CoCalc</font>](./sage_days_102_introduction_to_sage_13_sage_outside_jupyter_notebook.ipynb#cocalc)
#     * [ ]   [<font color=blue>SageMath Cell Server</font>](./sage_days_102_introduction_to_sage_13_sage_outside_jupyter_notebook.ipynb#sagemath-cell-server)
#     * [ ]   [<font color=blue>SageMath Shell</font>](./sage_days_102_introduction_to_sage_13_sage_outside_jupyter_notebook.ipynb#sagemath-shell)
#     * [ ]   [<font color=blue>The Old SageNB Notebook</font>](./sage_days_102_introduction_to_sage_13_sage_outside_jupyter_notebook.ipynb#the-old-sagenb-notebook)
# * [ ]   [<font color=blue>SageMath Resoruces</font>](./sage_days_102_introduction_to_sage_14_sagemath_resources.ipynb#sagemath-resources)
